# %%
import agent as myagents
import gym
import matplotlib.pyplot as plt
from tqdm import tqdm
import utils
import numpy as np
from IPython.display import clear_output
import time
import gym_CliffWorld

# %% [markdown]
# ### Environment

# %%
env = gym.make('FrozenLake8x8-v0')
seed = 12
train_session = None

# %% [markdown]
# ### Agent

# %% [markdown]
# #### Markovian decision process interpretation

# %%
num_action, num_state = env.action_space.n, env.observation_space.n

# %% [markdown]
# #### Agent config and hyperparameters

# %%
agent_init = {
    'seed': seed,
    'discount_factor': 1, 
    'learning_rate': 0.02, 
    'exploration_rate_decay': {
        'er': 0.1,
        'max_er': 1,
        'min_er': 0.0,
        'decay_er': 0.05,
        'constant_er': True
    },
    'eligibility_method': 'replace',
    'trace_decay': 0.9,
    'num_action': num_action,
    'num_state': num_state,
    'state_dim': (num_state, )
}

# %% [markdown]
# #### Creating Agent

# %%
if not train_session:
    print('Train Session reset')
    train_session = utils.TrainSession({}, env, seed)
# Out:
# Train Session reset

# %%
sarsa_agent = myagents.SarsaAgent(agent_init)
q_learning_agent = myagents.QLearningAgent(agent_init)
sarsa_lambda_agent = myagents.SarsaLambdaAgent(agent_init)
expected_sarsa_agent = myagents.ExpectedSarsaAgent(agent_init)

# %%
agents = {
    'sarsa': sarsa_agent,
    'q_learning': q_learning_agent,
    'expected_sarsa': expected_sarsa_agent,
    'sarsa_lambda': sarsa_lambda_agent
}

# %%
train_session.append_agents(agents)
# Out:
# ['sarsa', 'q_learning', 'expected_sarsa', 'sarsa_lambda']

# %% [markdown]
# ### Training

# %%
n_episode = 2000
t_max_per_episode = 500
graphical = False

# %%
train_session.train(n_episode=n_episode, graphical=graphical)
# Out:
# 100%|██████████| 5000/5000 [00:18<00:00, 271.31it/s]
# 100%|██████████| 5000/5000 [00:24<00:00, 205.25it/s]
# 100%|██████████| 5000/5000 [00:50<00:00, 99.17it/s]
# 100%|██████████| 5000/5000 [00:24<00:00, 204.76it/s]

# %%
train_session.plot_results(window=250)

# %% [markdown]
# #### HEATMAP

# %%
import seaborn as sb

# %%
for agent_name, agent in agents.items():
    sb.heatmap(agent.q.reshape(4, 8, 8).mean(axis=0)).set_title(agent_name)
    plt.show()

# %% [markdown]
# ### TESTING

# %%
n_episode_test = 4
agent_to_test = agents["expected_sarsa_agent"]
graphical = True

# %%
for i_episode in range(n_episode_test):
    
    rewards = 0
    state = env.reset()
    next_action = agent_to_test.episode_init(state)
    
    for t in range(t_max_per_episode):
        
        if graphical:
            clear_output(wait=True)
            env.render()
            time.sleep(0.2)
            
        
        state, reward, done, info = env.step(next_action)
        next_action = agent_to_test.e_greedy(state, always_greedy=True)
        if done:
            break

agent_to_test.exploration_handler.reset()
env.close()
# Out:
# SXXXXXXXXXXG
# ___________T
# ____________
# ____________
